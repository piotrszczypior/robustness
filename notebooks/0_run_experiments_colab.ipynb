# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/piotrszczypior/robustness
# %cd robustness/

# %% [markdown]
# ### Setup environment
#
# Downloading and extracting the required datasets and archives

# %%
# !python src/main.py setup --data-path data/ --dataset imagenet_c  --archives blur.tar

# %% [markdown]
# ### Run experiments
#
# Evaluation batch for the specified model and synchronizes the results with Google Drive.

# %%
# !python src/main.py evaluate --model convnext_base --experiments experiments/experiments.yaml --run-batch imagenet_c_blur --sync-drive
